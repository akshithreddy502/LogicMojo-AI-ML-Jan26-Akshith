# %% [markdown]
# ## TUPLES

# %%
list = [1,2,3,4] 
list[1]
list.append(5)
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## 1. Tuples - Immutable Sequences
#
# ### What are Tuples?
# - **Ordered** collection (like lists)
# - **Immutable** (cannot be changed after creation)
# - Created using parentheses `()` or just commas
#
# ### When to Use Tuples?
# 1. **Fixed data**: Coordinates `(x, y)`, RGB colors `(255, 0, 0)`
# 2. **Function returns**: Return multiple values
# 3. **Dictionary keys**: Tuples can be dict keys, lists cannot!
# 4. **Performance**: Faster than lists for iteration
# 5. **Data integrity**: Prevent accidental modifications
#
# ### ML Use Cases
# - Image dimensions: `(height, width, channels)`
# - Model architecture: `(input_size, hidden_size, output_size)`
# - Data shape: `tensor.shape` returns a tuple

# %% [markdown]
# point = (2,4)

# %%
# ========================================
# TUPLES: BASIC OPERATIONS
# ========================================

# Creating tuples
print("=== Creating Tuples ===")
point = (3, 5)
rgb = (255, 128, 0)
single = (42,)  # Note the comma! Without it, it's just a number
empty = ()
no_parens = 1, 2, 3  # Tuple packing

print(f"Point: {point}")
print(f"RGB: {rgb}")
print(f"Single element: {single}, type: {type(single)}")
print(f"Without comma: {(42)}, type: {type((42))}")
print(f"No parentheses: {no_parens}, type: {type(no_parens)}")

# Accessing elements (just like lists)
print("\n=== Accessing Elements ===")
print(f"First element: {point[0]}")
print(f"Last element: {rgb[-1]}")
print(f"Slicing: {rgb[1:3]}")

# Common operations
print("\n=== Common Operations ===")
print(f"Length: {len(rgb)}")
print(f"Count 255: {rgb.count(255)}")
print(f"Index of 128: {rgb.index(128)}")
print(f"Concatenation: {point + (7, 9)}")
print(f"Repetition: {(1, 2) * 3}")
# Out:
# === Creating Tuples ===
# Point: (3, 5)
# RGB: (255, 128, 0)
# Single element: (42,), type: <class 'tuple'>
# Without comma: 42, type: <class 'int'>
# No parentheses: (1, 2, 3), type: <class 'tuple'>
#
# === Accessing Elements ===
# First element: 3
# Last element: 0
# Slicing: (128, 0)
#
# === Common Operations ===
# Length: 3
# Count 255: 1
# Index of 128: 1
# Concatenation: (3, 5, 7, 9)
# Repetition: (1, 2, 1, 2, 1, 2)

# %%
# tuple with single value - add comma
tup = (3,)
type(tup)
# Out:
# tuple

# %%
point[0] = 10 # Immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 point[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(point)
# Out:
# 2

# %%
rgb = (0,255,0)
print(rgb.count(255)) # how many 255 are there in tuple
print(rgb.count(0))
# Out:
# 1
# 2

# %%
# ========================================
# TUPLE UNPACKING PATTERNS
# ========================================

# Basic unpacking
print("=== Basic Unpacking ===")
point = (10, 20)
x, y = point
print(f"x = {x}, y = {y}")


# Ignoring values with _
print("\n=== Ignoring Values ===")
rgb = (255, 128, 64)
red, _, _ = rgb  # We only care about red
print(f"Red channel: {red}")

# Unpacking in loops
print("\n=== Unpacking in Loops ===")
coordinates = [(0, 0), (1, 2), (3, 4)]
for x, y in coordinates:
# for: Loop through each item in an iterable (list, tuple, set, dict, etc.)
    print(f"Point: ({x}, {y})")

# Real ML example: unpacking batch data
print("\n=== ML Example: Batch Unpacking ===")
# Simulating a batch of (features, label) pairs
batch = [
    ([1.2, 3.4, 5.6], 0),
    ([2.1, 4.3, 6.5], 1),
    ([3.2, 5.4, 7.6], 0)
]

for features, label in batch:
# for: Loop through each item in an iterable (list, tuple, set, dict, etc.)
    print(f"Features: {features}, Label: {label}")
# Out:
# === Basic Unpacking ===
# x = 10, y = 20
#
# === Ignoring Values ===
# Red channel: 255
#
# === Unpacking in Loops ===
# Point: (0, 0)
# Point: (1, 2)
# Point: (3, 4)
#
# === ML Example: Batch Unpacking ===
# Features: [1.2, 3.4, 5.6], Label: 0
# Features: [2.1, 4.3, 6.5], Label: 1
# Features: [3.2, 5.4, 7.6], Label: 0

# %%
print(a)
# Out:
# 2

# %%
#Lits of tuples
coordinates = [(0,0),(1,2),(3,4)]
for x,y in coordinates:
    print(f"Point : ({x},{y})")
# Out:
# Point : (0,0)
# Point : (1,2)
# Point : (3,4)

# %% [markdown]
# # Advanced tuple techniques

# %%
# ========================================
# ADVANCED TUPLE PATTERNS
# ========================================

# Named tuples (from collections module)
print("=== Named Tuples ===")
from collections import namedtuple

# Define a Point type
Point = namedtuple('Point', ['x', 'y'])
p = Point(3, 5)
print(f"Point: {p}")
print(f"Access by name: p.x={p.x}, p.y={p.y}")
print(f"Access by index: p[0]={p[0]}, p[1]={p[1]}")

# ML example: Model configuration
ModelConfig = namedtuple('ModelConfig', ['input_size', 'hidden_size', 'output_size', 'dropout'])
config = ModelConfig(784, 256, 10, 0.5)
print(f"\nModel Config: {config}")
print(f"Hidden layer size: {config.hidden_size}")
# Out:
# === Named Tuples ===
# Point: Point(x=3, y=5)
# Access by name: p.x=3, p.y=5
# Access by index: p[0]=3, p[1]=5
#
# Model Config: ModelConfig(input_size=784, hidden_size=256, output_size=10, dropout=0.5)
# Hidden layer size: 256

# %% [markdown]
# ## SETS

# %% [markdown]
# Sets are unordered collection of unique elements
# use {} curly braces
# Mutable
# Based on hash tables -> very fast lookups

# %% [markdown]
# When to use:
# Remove duplicates from a list
# Set operations: Union,intersection, difference

# %% [markdown]
# ## 2. Sets - Unique Elements Collection
#
# ### What are Sets?
# - **Unordered** collection of **unique** elements
# - Created using curly braces `{}` or `set()`
# - **Mutable** (can add/remove elements)
# - Based on hash tables → **very fast** lookups!
#
# ### When to Use Sets?
# 1. **Remove duplicates** from a list
# 2. **Membership testing**: "Is X in the collection?"
# 3. **Set operations**: Union, intersection, difference
# 4. **Unique value tracking**: Track unique users, unique words, etc.
#
# ### 📊 ML Use Cases
# - Vocabulary creation (unique words in text)
# - Label validation (ensure all labels are from expected set)
# - Feature engineering (unique categories)
# - Data cleaning (find unique values, duplicates)
#
# ### Performance Tip
# ```python
# # Checking if item in collection:
# item in my_list    # O(n) - slow for large lists
# item in my_set     # O(1) - instant! -> Becasue set uses hash tables , noy linear search
# ```

# %%
# ========================================
# SETS: BASIC OPERATIONS
# ========================================

# Creating sets


print("=== Creating Sets ===")
fruits = {'apple', 'banana', 'cherry'}
numbers = set[int]([1, 2, 3, 2, 1])  # Duplicates removed!
empty_set = set()  # Note: {} creates an empty dict, not set!

print(f"Fruits: {fruits}")
print(f"Numbers (duplicates removed): {numbers}")
print(f"Empty set: {empty_set}, type: {type(empty_set)}")
print(f"Empty dict: {{}}, type: {type({})}")

# Adding and removing
print("\n=== Adding and Removing ===")
fruits.add('mango')
# .add(): Add a single element to the set (no effect if already exists)
print(f"After add: {fruits}")

fruits.remove('banana')  # Raises KeyError if not found
print(f"After remove: {fruits}")

fruits.discard('grape')  # No error if not found
print(f"After discard (non-existent): {fruits}")

popped = fruits.pop()  # Remove and return arbitrary element
print(f"Popped: {popped}, Remaining: {fruits}")

# Membership testing (FAST!)
print("\n=== Membership Testing ===")
print(f"'apple' in fruits: {'apple' in fruits}")
print(f"'banana' in fruits: {'banana' in fruits}")

# Real ML example: Unique labels
print("\n=== ML Example: Finding Unique Labels ===")
labels = [0, 1, 0, 0, 1, 2, 1, 0, 2, 1, 1, 0]
unique_labels = set(labels)
# set(): Create a set - unordered collection of unique elements, O(1) lookup
print(f"All labels: {labels}")
print(f"Unique labels: {unique_labels}")
print(f"Number of classes: {len(unique_labels)}")
# Out:
# === Creating Sets ===
# Fruits: {'cherry', 'banana', 'apple'}
# Numbers (duplicates removed): {1, 2, 3}
# Empty set: set(), type: <class 'set'>
# Empty dict: {}, type: <class 'dict'>
#
# === Adding and Removing ===
# After add: {'mango', 'cherry', 'banana', 'apple'}
# After remove: {'mango', 'cherry', 'apple'}
# After discard (non-existent): {'mango', 'cherry', 'apple'}
# Popped: mango, Remaining: {'cherry', 'apple'}
#
# === Membership Testing ===
# 'apple' in fruits: True
# 'banana' in fruits: False
#
# === ML Example: Finding Unique Labels ===
# All labels: [0, 1, 0, 0, 1, 2, 1, 0, 2, 1, 1, 0]
# Unique labels: {0, 1, 2}
# Number of classes: 3

# %%
empty_set = set() # dont use {} as it creates dictionary
type(empty_set)
# Out:
# set

# %%
fruits.add('orange')
print(fruits)

fruits.remove('cherry')
print(fruits)
# Out:
# {'banana', 'orange', 'cherry', 'apple'}
# {'banana', 'orange', 'apple'}

# %%
'apple' in fruits
# Out:
# True

# %%
A= {1,2,3,4,5}
B={5,6,7,8,9}
print(A.union(B))
print(A.intersection(B))
print(A-B) # take A and subtract B or A.difference(B)
print(B-A) #B.difference(A)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {5}
# {1, 2, 3, 4}
# {8, 9, 6, 7}

# %%
print("=== Example 1: Building Vocabulary ===")
documents = [
    "machine learning is awesome",
    "deep learning is powerful",
    "machine learning and deep learning"
]

## Question: Build a vocabulary set of unique words from these documents
parstr =" ".join(documents)
newStr = parstr.split(" ")
print(newStr)


vocabulary = set() # set stores only unique words
for doc in documents:
    words = doc.lower.split()
    vocabulary.update(words)
# Out:
# === Example 1: Building Vocabulary ===
# ['machine', 'learning', 'is', 'awesome', 'deep', 'learning', 'is', 'powerful', 'machine', 'learning', 'and', 'deep', 'learning']

# %%
A = {1,2,3,4,5}
B= {1,2,3}
B.issubset(A) # is all elements of B present in A

# %%
# ========================================
# SETS IN ML: PRACTICAL EXAMPLES
# ========================================

# Example 1: Text Vocabulary
print("=== Example 1: Building Vocabulary ===")
documents = [
    "machine learning is awesome",
    "deep learning is powerful",
    "machine learning and deep learning"
]

# Build vocabulary (unique words)
vocabulary = set()
# set(): Create a set - unordered collection of unique elements, O(1) lookup
for doc in documents:
# for: Loop through each item in an iterable (list, tuple, set, dict, etc.)
    words = doc.split()
    vocabulary.update(words)  # Add all words to set

print(f"Vocabulary: {vocabulary}")
print(f"Vocabulary size: {len(vocabulary)}")

# Example 2: Train-Test Split Validation
print("\n=== Example 2: Checking Data Leakage ===")
train_ids = {1, 2, 3, 4, 5, 6, 7, 8}
test_ids = {9, 10, 11, 12}

# Check for overlap (data leakage!)
overlap = train_ids & test_ids # set Interesction
if overlap:
# if: Execute code block only if condition is True
    print(f"⚠️ WARNING: Data leakage detected! Overlap: {overlap}")
else:
# else: Execute if all previous if/elif conditions were False
    print("✓ No data leakage - train and test are disjoint")

# Example 3: Label Validation
print("\n=== Example 3: Validating Labels ===")
expected_labels = {'cat', 'dog', 'bird'}
actual_labels = ['cat', 'dog', 'cat', 'bird', 'fish', 'cat']

actual_label_set = set(actual_labels) #actual_label_set = {'cat', 'dog', 'bird', 'fish'} -> Rempves duplicates when added to Set

# set(): Create a set - unordered collection of unique elements, O(1) lookup
unexpected = actual_label_set - expected_labels # Elements that are in A But not in B -> remove only the elements that appear in BOTH A and B

if unexpected:
# if: Execute code block only if condition is True
    print(f"⚠️ Unexpected labels found: {unexpected}")
else:
# else: Execute if all previous if/elif conditions were False
    print("✓ All labels are valid")


# Set common operations
common = actual_label_set & expected_labels
print(f"Intersaction is - {common}")

# A-B => Elements that are in A but NOT in B

#Keep only elements unique to A
#Do not include elements that appear in both A and B
commonA_B = actual_label_set - expected_labels
print(f"A-B is - {commonA_B}")

#Keep only elements unique to B
#Do not include elements that appear in both A and B
commonB_A =   expected_labels - actual_label_set
print(f"B-A is - {commonB_A}")

#Union (|) — All labels seen anywhere
commonUnion = expected_labels | actual_label_set
print(f"Union is - {commonUnion}")

#Symmetric Difference (^) — Mismatch labels
mismatch =    actual_label_set ^ expected_labels 
print(f"Mismatch is - {mismatch}")




# Example 4: Finding Common Features
print("\n=== Example 4: Feature Selection ===")
features_dataset1 = {'age', 'height', 'weight', 'income', 'education'}
features_dataset2 = {'age', 'weight', 'occupation', 'income', 'city'}

common_features = features_dataset1 & features_dataset2
print(f"Common features: {common_features}")

unique_to_dataset1 = features_dataset1 - features_dataset2
unique_to_dataset2 = features_dataset2 - features_dataset1
print(f"Unique to dataset 1: {unique_to_dataset1}")
print(f"Unique to dataset 2: {unique_to_dataset2}")
# Out:
# === Example 1: Building Vocabulary ===
# Vocabulary: {'learning', 'is', 'awesome', 'machine', 'and', 'deep', 'powerful'}
# Vocabulary size: 7
#
# === Example 2: Checking Data Leakage ===
# ✓ No data leakage - train and test are disjoint
#
# === Example 3: Validating Labels ===
# ⚠️ Unexpected labels found: {'fish'}
# Intersaction is - {'dog', 'bird', 'cat'}
# A-B is - {'fish'}
# B-A is - set()
# Union is - {'bird', 'fish', 'dog', 'cat'}
# Mismatch is - {'fish'}
#
# === Example 4: Feature Selection ===
# Common features: {'income', 'age', 'weight'}
# Unique to dataset 1: {'education', 'height'}
# Unique to dataset 2: {'occupation', 'city'}

# %% [markdown]
# ## DICTIONARY

# %%
### SEARCH IN O(1)
# UNORDERED COLLECTION OF KEY - VALUE PAIRS
# CREATED USING {} OR DICT()

# %%
word = {}
type(word)
# Out:
# dict

# %%
employee_slary = {
    "Akshith": 5000,
    "Praveen": 6000,
    "Sandhya": 7000
}
employee_slary["Praveen"]
# Out:
# 6000

# %%
# When to use:
# 1) Lookup by name/ID
# 2)count occurency of items

# ML use cases:
# Word Frequency counts
#Feature mappings (label encoding)

# Performance:
# Lookup, insert,delete : O(1)
# Much faster than lists for searching

# %%
# Hashmap or Dictionary
student = {'name':'Akshith','age':30,'grade':'A'}
empty_dict = {}

print(type(student),student)
print(type(empty_dict),empty_dict)
# Out:
# <class 'dict'> {'name': 'Akshith', 'age': 30, 'grade': 'A'}
# <class 'dict'> {}

# %%
# Access values:
student['name']
# Out:
# 'Akshith'

# %%
student.get('name') # Best way to access a value from dict
# Out:
# 'Akshith'

# %%
# Adding and Modifying

student['email'] = 'akshithreddy' # inserting IMP

# %%
print(student)
# Out:
# {'name': 'Akshith', 'age': 30, 'grade': 'A', 'email': 'akshithreddy'}

# %%
del student['grade']

# %%
print(student)
# Out:
# {'name': 'Akshith', 'age': 30, 'email': 'akshithreddy'}

# %%
for stu in student:
    print(student[stu])
# Out:
# Akshith
# 30
# akshithreddy

# %%
popped_email = student.pop('email')
print(popped_email)
# Out:
# akshithreddy

# %%
# Dictionary methods:

print(student)
# Out:
# {'name': 'Akshith', 'age': 30}

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'age'])
# dict_values(['Akshith', 30])
# dict_items([('name', 'Akshith'), ('age', 30)])

# %%
for key,value in student.items():
    print(f"{key} scored {value}")
# Out:
# name scored Akshith
# age scored 30

# %%
#1: Word Frequency Count
text = "machine learning is great machine learning is powerful learning is fun"

dict = {}
words = text.lower().split()
for word in words:
    if word in dict: ##### IMMMMMMPPPPP
        dict[word] += 1
    else:
        dict[word] = 1
print(dict)
# Out:
# {'machine': 2, 'learning': 3, 'is': 3, 'great': 1, 'powerful': 1, 'fun': 1}

# %% [markdown]
# ## FUNCTIONS

# %%
def sum_values(a,b):
    """
    Docstring for sum_values
    
    :param a: Description
    :param b: Description
    """ 
    total = a+b
    return total

print(sum_values(1,2))
print(sum_values(a=1,b=2)) # keyword parameters
# Out:
# 3
# 3

# %%
def sum_values(a,b=4): # default parameters
    """
    Docstring for sum_values
    
    :param a: Description
    :param b: Description
    """ 
    total = a+b
    return total

print(sum_values(1,2))
print(sum_values(a=1,b=2)) # keyword parameteres
print(sum_values(1)) # uses dafault parameters
# Out:
# 3
# 3
# 5

# %%
import pandas as pd
data = pd.DataFrame({
    'Age': [25, 30, None, 35, 40],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Salary': [50000, 60000, 70000, None, 90000]
})

# %%
data.shape
# Out:
# (5, 3)
