# %% [markdown]
# What are Gen AI Frameworks
# Vector DB => diff vector db (open source and closed source)
# Application of Vector DB
# What is Tools
# What are different types of RAG
# How LLM uses Tools
# What are agents
# what is the difference bw agent and static progaramming
# Pros abd cons of Agents
