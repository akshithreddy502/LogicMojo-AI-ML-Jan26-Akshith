# %% [markdown]
# ## STATISTICS

# %% [markdown]
# Collecting, Organizing, Analysing, Interpreting, Presenting the data - Statistics

# %% [markdown]
# Why Stats - To find patterns recognition
# -Data cleaning
# -Feature engineering
# -Model evaluation

# %% [markdown]
# Data Types and Stats:
#
# 1) Quantitative analysis - Data that can be measured
#
#             Continuous data - Measurable data - height, weight, temperature
#             Discrete data -  Countable data set - No of students , number of cars in a parking lot - you cannot have 2.5 students and 3.7 cars
#
# 2) Qualitative analysis - Categorical data - Data that represents categories, labels - Color, gender, blood group, marital status
#
#         Nominal Data - Categories without order - eye color, country
#         ordinal data - order
#
#         Good < Better < Best>
#         Size- s < m < L < xl

# %% [markdown]
# Measure of Central tendency

# %% [markdown]
# THis tells where the centre of data lies - single value that represents the whole dataset.

# %% [markdown]
# 1️⃣ Mean (Average)
#
# 📌 What it is
#
# Add all values and divide by how many values there are.
#
# 🧮 Formula
#
# Mean = (sum of values) / (number of values)
#
# Example
#
# Data: 2, 4, 6, 8
#
# Mean = (2 + 4 + 6 + 8) / 4 = 5
#
# ✅ Used a lot
# ❌ Very sensitive to outliers
#
# ⸻
#
# 2️⃣ Median (Middle value)
#
# 📌 What it is
#
# The middle value when data is sorted.
#
# Example (odd count)
#
# Data: 3, 5, 7, 9, 11
# Median = 7
#
# Example (even count)
#
# Data: 2, 4, 6, 8
# Median = (4 + 6) / 2 = 5
#
# ✅ Not affected by outliers
# 👉 Very useful for income, salary, house prices
#
# ⸻
#
# 3️⃣ Mode (Most frequent value)
#
# 📌 What it is
#
# The value that appears most often.
#
# Example
#
# Data: 1, 2, 2, 3, 4
# Mode = 2
#
# ✔ Can be more than one mode
# ✔ Can be used for qualitative data
#
# Example:
# Colors → red, blue, blue, green
# Mode = blue

# %% [markdown]
# ## Outlier example (very important)
#
# Salaries:
# 40k, 45k, 50k, 55k, 1,000k
# 	•	Mean → 238k ❌ misleading
# 	•	Median → 50k ✅ realistic
#
# 👉 That’s why median salary is often reported.

# %% [markdown]
# ## When to Use Mean
#
# Use mean when:
#
# ✅ Data is symmetrical
# ✅ No extreme outliers
# ✅ Values are fairly close to each other
# ✅ You want a true mathematical average
#
# Examples
# 	•	Exam scores where most students score similarly
# 	•	Average temperature of a city
# 	•	Average test execution time (no spikes)
#
# 📌 Why?
# Mean uses every value, so it works best when all values are “normal”.
#
# ⸻

# %% [markdown]
# ## When to Use Median
#
# Use median when:
#
# ✅ Data is skewed (left or right)
# ✅ Outliers exist
# ✅ You want the typical real-world value
# ✅ Data represents money, income, prices
#
# Examples
# 	•	Salaries
# 	•	House prices
# 	•	Insurance claims
# 	•	Time spent on a website (some users stay very long)

# %% [markdown]
# ## Measure of Dispersion(spread of data)

# %% [markdown]
# Range = max - min

# %% [markdown]
# ## VARIANCE
# Average of squared distances from the mean.
#
# Steps (conceptually)
#
# 	1.	Find the mean
#
# 	2.	Subtract mean from each value
#
# 	3.	Square the differences
#
# 	4.	Take the average
#
# Why square?
# 	•	Removes negative values
# 	•	Penalizes large deviations
#
# ❌ Unit becomes squared (not intuitive)

# %% [markdown]
# # Standard Deviation - root of variance
#
# Why do we use Standard Deviation (SD) instead of Variance?
#
# ⸻
#
# 1️⃣ Same unit as the data (BIGGEST reason)
# 	•	Variance squares the units
# 	•	Height in cm → variance in cm² ❌
# 	•	Standard Deviation takes the square root
# 	•	Back to cm ✅
#
# 📌 This makes SD easy to understand and explain.
#
# Example:
# 	•	Mean height = 170 cm
# 	•	SD = 5 cm → “Most heights are within 5 cm of the average” ✔
# 	•	Variance = 25 cm² → not intuitive ❌
#
# ⸻
#
# 2️⃣ SD is interpretable in real life
# 	•	SD answers:
# 👉 “How far is a typical value from the mean?”
# 	•	Variance answers:
# 👉 “What is the average squared deviation?”
# (Useful mathematically, not human-friendly)
#
# ⸻
#
# 3️⃣ Same scale → easy comparison
#
# If two datasets have:
# 	•	SD = 4 vs SD = 10 → instantly clear which is more spread out
#
# With variance:
# 	•	16 vs 100 → harder to relate back to data scale

# %% [markdown]
# PROBABILITY AND DISTRIBUTION:

# %% [markdown]
# Probability: Measure of likelihood of an event
#
# P(A) = No of times a certain event has occured/ Total No
#
#                 P(A) = No of likelihood /Total
#
#                 Eg: Coin - Head / Tail = P(H) = 1/2
#
#                     Dice - Probability of 4 = 1/6
#
#                          - Probability of even numbers = 3/6 => 1/2

# %% [markdown]
# Independent Events
#
# Definition:
# Two events are independent if the occurrence of one does NOT affect the probability of the other.
#
# 👉 In short: One event has no influence on the other.
#
# Example 1: Tossing a coin twice
# 	•	Event A: First toss is Heads
# 	•	Event B: Second toss is Heads
#
# The first toss doesn’t change the second toss.
# So these events are independent.
#
# Probability rule:
#
# P(A and B) = P(A) * P(B)
#
# Example:
# 	•	P(Heads) = 1/2
# 	•	P(Heads on both tosses) = 1/2 × 1/2 = 1/4
#
# ⸻
#
# 🔗 Dependent Events
#
# Definition:
# Two events are dependent if the occurrence of one does affect the probability of the other.
#
# 👉 In short: The first event changes the chances of the second.
#
# Example 2: Drawing cards without replacement
# 	•	Event A: First card is an Ace
# 	•	Event B: Second card is an Ace
#
# After drawing one Ace, fewer Aces remain → probability changes.
# So these events are dependent.
#
# Probability rule:
#
# P(A and B) = P(A) * P(B|A)
#
# Example:
# 	•	P(First Ace) = 4/52
# 	•	P(Second Ace | first was Ace) = 3/51
# 	•	Combined = (4/52) × (3/51)

# %% [markdown]
# ## Gaussian (Normal) Distribution — Beginner Explanation
#
# 📌 What is it?
#
# The Gaussian distribution describes how values are spread around an average.
#
# 👉 Most values are near the middle,
# 👉 Fewer values are far away from the middle.
#
# It forms a bell-shaped curve 🔔
#
# ⸻
#
# 🎯 Real-Life Intuition
#
# Think about human height:
# 	•	Most people are around average height
# 	•	Very tall or very short people are rare
#
# That pattern follows a Gaussian distribution.
#
# ⸻
#
# 📊 The Bell Curve Idea (No Formula Yet)
# 	•	The center of the curve = Mean (average)
# 	•	The curve is symmetric
# 	•	Left side = smaller values
# 	•	Right side = larger values
#
# So:
# 	•	Many values in the middle
# 	•	Very few at the extremes
#
# ⸻
#
# 🧠 Key Terms (Very Important)
#
# 1️⃣ Mean (μ)
# 	•	The average
# 	•	Center of the curve
#
# 2️⃣ Standard Deviation (σ)
# 	•	Tells us how spread out the data is
# 	•	Small σ → data tightly packed
# 	•	Large σ → data more spread out
#
# ⸻
#
# 📏 The 68–95–99.7 Rule (Easy to Remember)
#
# In a Gaussian distribution:
# 	•	68% of data lies within 1σ of the mean
# 	•	95% lies within 2σ
# 	•	99.7% lies within 3σ
