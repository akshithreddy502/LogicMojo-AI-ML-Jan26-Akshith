# %% [markdown]
# ## Data Types and Conditionals

# %%
# Example 1 - Create 5 variables (your choice) and print each value with its type
x = 10
print(x,type(x))

name = "Akshith"
print(name,type(name))

num = 3.2
print(num,type(num))

arr = [1,2,3,4,5]
print(arr,type(arr))

flag = True
print(flag,type(flag))
# Out:
# 10 <class 'int'>
# Akshith <class 'str'>
# 3.2 <class 'float'>
# [1, 2, 3, 4, 5] <class 'list'>
# True <class 'bool'>
