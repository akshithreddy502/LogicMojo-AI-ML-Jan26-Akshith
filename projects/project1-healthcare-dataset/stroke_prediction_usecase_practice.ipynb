# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
el_path = "/Users/akshith/Documents/LogicMojo-AI-ML-Jan26-Akshith/projects/project1-healthcare-dataset/healthcare-dataset-stroke-data.csv"

# %%
df = pd.read_csv(el_path)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.describe() # only gives numeric columns
df.describe(include='all')
# Out:
#                   id  gender          age  hypertension  heart_disease  \
# count    5110.000000    5110  5110.000000   5110.000000    5110.000000
# unique           NaN       3          NaN           NaN            NaN
# top              NaN  Female          NaN           NaN            NaN
# freq             NaN    2994          NaN           NaN            NaN
# mean    36517.829354     NaN    43.226614      0.097456       0.054012
# std     21161.721625     NaN    22.612647      0.296607       0.226063
# min        67.000000     NaN     0.080000      0.000000       0.000000
# 25%     17741.250000     NaN    25.000000      0.000000       0.000000
# 50%     36932.000000     NaN    45.000000      0.000000       0.000000
# 75%     54682.000000     NaN    61.000000      0.000000       0.000000
# max     72940.000000     NaN    82.000000      1.000000       1.000000
#
#        ever_married work_type Residence_type  avg_glucose_level          bmi  \
# count          5110      5110           5110        5110.000000  4909.000000
# unique            2         5              2                NaN          NaN
# top             Yes   Private          Urban                NaN          NaN
# freq           3353      2925           2596                NaN          NaN
# mean            NaN       NaN            NaN         106.147677    28.893237
# std             NaN       NaN            NaN          45.283560     7.854067
# min             NaN       NaN            NaN          55.120000    10.300000
# 25%             NaN       NaN            NaN          77.245000    23.500000
# 50%             NaN       NaN            NaN          91.885000    28.100000
# 75%             NaN       NaN            NaN         114.090000    33.100000
# max             NaN       NaN            NaN         271.740000    97.600000
#
#        smoking_status       stroke
# count            5110  5110.000000
# unique              4          NaN
# top      never smoked          NaN
# freq             1892          NaN
# mean              NaN     0.048728
# std               NaN     0.215320
# min               NaN     0.000000
# 25%               NaN     0.000000
# 50%               NaN     0.000000
# 75%               NaN     0.000000
# max               NaN     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# # EDA - EXPLORARTORY DATA ANALYSIS

# %%
target_col = 'stroke'
id_col = 'id'
categoriacl_cols = df.select_dtypes(include=['object']).columns.tolist()

numerical_cols = df.select_dtypes(exclude=['object']).columns.tolist()

# %%
categoriacl_cols
# Out:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
numerical_cols
# Out:
# ['id',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'avg_glucose_level',
#  'bmi',
#  'stroke']

# %%
df['hypertension'].value_counts()
# Out:
# hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64

# %%
numerical_cols.remove(target_col)
numerical_cols.remove(id_col) # we will analyze saperatley

# %%
numerical_cols
# Out:
# ['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi']

# %%
numeric_cols = []
for col in numerical_cols:
    if df[col].nunique()<10:
        categoriacl_cols.append(col)
    else:
        numeric_cols.append(col)

# %%
print(numeric_cols)
print(categoriacl_cols)
# Out:
# ['age', 'avg_glucose_level', 'bmi']
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status', 'hypertension', 'heart_disease']

# %% [markdown]
# # Univariate Analysis - One column analysis at a time

# %%
plt.figure(figsize=(15, 12))

for i, col in enumerate(categoriacl_cols):
    ax = plt.subplot(3, 3, i + 1)
    
    sns.countplot(data=df, x=col, palette='Set2')
    
    plt.title(f'Distribution of {col}', fontsize=12)
    plt.xlabel('')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    
    total = len(df)
    for p in ax.patches:
        percentage = f'{100 * p.get_height() / total:.1f}%'
        x = p.get_x() + p.get_width() / 2
        y = p.get_height()
        ax.annotate(percentage, (x, y), ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1547887828.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1547887828.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1547887828.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1547887828.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1547887828.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1547887828.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1547887828.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')

# %% [markdown]
# # Numerical columns

# %%
# Hist plot
plt.figure(figsize=(15, 4))

for i, col in enumerate(numeric_cols):
    ax = plt.subplot(3, 3, i + 1)
    
    sns.histplot(data=df, x=col, palette='Set2')
    
    plt.title(f'Distribution of {col}', fontsize=12)
    plt.xlabel('')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1323004891.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1323004891.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1323004891.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=col, palette='Set2')

# %%
# Box Plot
plt.figure(figsize=(15, 15))

for i, col in enumerate(numeric_cols):
    ax = plt.subplot(3, 3, i + 1) # 3 rows 3 cols
    
    sns.boxplot(data=df, x=col, palette='Set2')
    
    plt.title(f'Distribution of {col}', fontsize=12)
    plt.xlabel('')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_72972/2999968611.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_72972/2999968611.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, palette='Set2')
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_72972/2999968611.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, palette='Set2')

# %% [markdown]
# # Target Column

# %%
stroke_counts = df[target_col].value_counts()

# %%
stroke_counts
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %% [markdown]
# # only 249 of total has chance of stroke

# %%
# Count the occurrences of each class in the target variable
stroke_counts = df[target_col].value_counts()
print(stroke_counts)

# Visualize the distribution of the target
plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df, x=target_col, palette='viridis')
plt.title('Distribution of Stroke (Target Variable)')
plt.xlabel('Stroke (0 = No, 1 = Yes)')
plt.ylabel('Count')

# Add percentage to each bar
total = len(df)
for p in ax.patches:
    percentage = f'{100 * p.get_height() / total:.1f}%'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='bottom')

plt.show()

# Print exact numbers proportion
print("\nProportions:\n", df[target_col].value_counts(normalize=True))
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64
# /var/folders/4s/sdqr5khs4s1g01jxv1jnq_7w0000gn/T/ipykernel_22068/1350994585.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x=target_col, palette='viridis')
# Proportions:
#  stroke
# 0    0.951272
# 1    0.048728
# Name: proportion, dtype: float64

# %% [markdown]
# # ETA TOOLS:
# PANDAS PROFILING # FOR MORE COLS LIKE 200 COLS
#
# AUTOVIZ

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer # impute null values
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
# Define our custom feature engineering functions
from sklearn.pipeline import FunctionTransformer


def categorize_features(df_in):
    df = df_in.copy()

    # 1. High Glucose Flag
    df['is_high_glucose'] = (df['avg_glucose_level'] > 150).astype(int)

    # 2. BMI Categories
    bins = [0, 18.5, 25, 30, 100]
    labels = ['Underweight', 'Normal', 'Overweight', 'Obese']

    # Use fillna to handle missing BMI values temporarily before the imputer catches them
    df['bmi_category'] = pd.cut(
        df['bmi'].fillna(df['bmi'].median()),
        bins=bins,
        labels=labels
    )

    # 3. Age Categories
    age_bins = [0, 18, 65, 150]
    age_labels = ['Child', 'Adult', 'Senior']

    df['age_category'] = pd.cut(
        df['age'],
        bins=age_bins,
        labels=age_labels
    )

    # 4. Health Risk Score (Sum of risk factors)
    df['health_risk_score'] = (
        (df['age_category'] == 'Senior').astype(int) +
        df['hypertension'] +
        df['heart_disease'] +
        (df['bmi_category'].isin(['Overweight', 'Obese'])).astype(int) +
        (df['smoking_status'] == 'smokes').astype(int)
    )

    return df

custom_fe = FunctionTransformer(categorize_features)

# %%
custom_fe
# Out:
# FunctionTransformer(func=<function categorize_features at 0x17917a8e0>)

# %% [markdown]
# ### 2.3 Bivariate Analysis (Features vs. Target)
# Now we look at *two* variables at a time to see how our features relate to our target variable.

# %%
# 1. Categorical vs Target (Stroke)
# We use countplots and the 'hue' parameter to separate the bars by Stroke outcome
plt.figure(figsize=(18, 12))
for i, col in enumerate(categoriacl_cols):
    ax = plt.subplot(3, 3, i + 1)
    
    # Plotting the countplot with hue='stroke'
    sns.countplot(data=df, x=col, hue=target_col, palette='Set1')
    plt.title(f'{col} vs Stroke', fontsize=12)
    plt.xlabel('')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    
    # Calculate and display percentages on top of the bars
    # Since there's 'hue', we calculate the percentage relative to the sub-category total
    # e.g., what % of Males had a stroke vs no stroke.
    
    # Store heights to calculate bin totals
    patches = ax.patches
    half = len(patches) // 2
    
    for j in range(half):
        # The first half of patches belongs to 'No Stroke' (class 0)
        p1 = patches[j]
        # The second half of patches belongs to 'Stroke' (class 1)
        p2 = patches[j + half]
        
        # Total count for this specific category (e.g. Total Males)
        total_for_category = p1.get_height() + p2.get_height()
        
        if total_for_category > 0:
            # Annotate Class 0 (No Stroke)
            p1_pct = f'{100 * p1.get_height() / total_for_category:.1f}%'
            ax.annotate(p1_pct, (p1.get_x() + p1.get_width() / 2, p1.get_height()), ha='center', va='bottom', fontsize=9)
            
            # Annotate Class 1 (Stroke)
            p2_pct = f'{100 * p2.get_height() / total_for_category:.1f}%'
            ax.annotate(p2_pct, (p2.get_x() + p2.get_width() / 2, p2.get_height()), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()
